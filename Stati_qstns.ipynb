# %%
import pandas as pd

# %%
tip=pd.read_csv("tips.csv")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Q.1) what is the average tip of each sex

# %%
grouped_tip=tip.groupby('sex')
grouped_tip['tip'].mean()
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %% [markdown]
# ### Q.2) What is The Sum Of Total Bills For Each

# %%
grouped=tip.groupby('sex')
grouped['total_bill'].sum()
# Out:
# sex
# Female    1570.95
# Male      3256.82
# Name: total_bill, dtype: float64

# %% [markdown]
# ### Q.3) What Is The Number Of Unique Days In Each

# %%
grouped=tip.groupby('sex')
grouped['day'].unique()
# Out:
# sex
# Female    [Sun, Sat, Thur, Fri]
# Male      [Sun, Sat, Thur, Fri]
# Name: day, dtype: object

# %% [markdown]
# ### Q4) Country Group By Employments

# %%
df=pd.read_csv("survey_results_public.csv")
pd.set_option("display.max_columns",85)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
country_group=df.groupby("Country")

# %%
country_group['Employment'].get_group('Pakistan')
# Out:
# 83                                      Employed full-time
# 118                                     Employed full-time
# 296                                                    NaN
# 297                                     Employed part-time
# 309                                     Employed full-time
#                                ...
# 88310    Independent contractor, freelancer, or self-em...
# 88353                   Not employed, but looking for work
# 88567                   Not employed, but looking for work
# 88710               Not employed, and not looking for work
# 88875                                   Employed part-time
# Name: Employment, Length: 923, dtype: object

# %% [markdown]
# ### Q5)

# %%
country_group['Employment'].get_group('Thailand')
# Out:
# 2                                       Employed full-time
# 253      Independent contractor, freelancer, or self-em...
# 733                                     Employed full-time
# 1595                                    Employed full-time
# 1653                                                   NaN
#                                ...
# 88669                                   Employed full-time
# 88763               Not employed, and not looking for work
# 88765                                   Employed part-time
# 88802                                   Employed full-time
# 88846                                   Employed full-time
# Name: Employment, Length: 214, dtype: object

# %% [markdown]
# ### Q6) Retired Indian Employees

# %%
country_group['Employment'].get_group('India').str.contains("Retired").value_counts(normalize=True)
# Out:
# False    0.999432
# True     0.000568
# Name: Employment, dtype: float64

# %% [markdown]
# ### Q7)Twitter Users In India

# %%
social_group=df.groupby('SocialMedia')

# %%
social_group['Country'].get_group('Twitter').str.contains('India').value_counts(normalize=True)
# Out:
# False    0.952448
# True     0.047552
# Name: Country, dtype: float64

# %% [markdown]
# ### Q8) Facebook Users In Thailand

# %%
social_group['Country'].get_group('Facebook').str.contains('Thailand').value_counts(normalize=True)
# Out:
# False    0.992639
# True     0.007361
# Name: Country, dtype: float64

# %% [markdown]
# ### Q9) Both Highest Tip

# %%
grouped=tip.groupby('sex')
grouped['tip'].max()
# Out:
# sex
# Female     6.5
# Male      10.0
# Name: tip, dtype: float64

# %% [markdown]
# ### Q10) Highest Bill

# %%
grouped=tip.groupby('sex')
grouped['total_bill'].max()
# Out:
# sex
# Female    44.30
# Male      50.81
# Name: total_bill, dtype: float64

# %% [markdown]
# ### Q11)

# %%
obj=df.groupby('Country')
obj

# %%
obj.groups
# Out:
# {'Afghanistan': [719, 6391, 7056, 7323, 8112, 10697, 12253, 22327, 26189, 28470, 28877, 29560, 32971, 37571, 39018, 39754, 42832, 44123, 45562, 46807, 48122, 49377, 50172, 50437, 51525, 58082, 58390, 59184, 60185, 60559, 61770, 62124, 62723, 73920, 80423, 85185, 85293, 85827, 86394, 86551, 88033, 88181, 88340, 88735], 'Albania': [1946, 2324, 3771, 6181, 6688, 9190, 9230, 9401, 10257, 10480, 10886, 11496, 12208, 13322, 15295, 15461, 15910, 16070, 18027, 18193, 18734, 18766, 20030, 20300, 21584, 21638, 24955, 24964, 25440, 26040, 27476, 28705, 28995, 29243, 33177, 33385, 33999, 35805, 36348, 37134, 38075, 38693, 38869, 40574, 41344, 41713, 43601, 43790, 46829, 49389, 49431, 50000, 54739, 55041, 55196, 55553, 55572, 55994, 57057, 58394, 59763, 59980, 61881, 62229, 62511, 64380, 64495, 64605, 64815, 65859, 67086, 68553, 69716, 69857, 70187, 70280, 73036, 76073, 76755, 78326, 79906, 79936, 80012, 84729, 85346, 88778], 'Algeria': [1098, 1536, 3060, 3286, 3441, 3600, 4154, 4302, 4363, 4373,
# ...

# %% [markdown]
# ### Q12) Country Contains With Rows

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
for WorkLoc,group in obj:
    print(WorkLoc,'contains',group.shape[0],'rows')
# Out:
# Afghanistan contains 44 rows
# Albania contains 86 rows
# Algeria contains 134 rows
# Andorra contains 7 rows
# Angola contains 5 rows
# Antigua and Barbuda contains 9 rows
# Argentina contains 553 rows
# Armenia contains 86 rows
# Australia contains 1903 rows
# Austria contains 839 rows
# Azerbaijan contains 49 rows
# Bahamas contains 3 rows
# Bahrain contains 18 rows
# Bangladesh contains 605 rows
# Barbados contains 3 rows
# Belarus contains 202 rows
# Belgium contains 727 rows
# Belize contains 3 rows
# Benin contains 5 rows
# Bhutan contains 2 rows
# Bolivia contains 36 rows
# Bosnia and Herzegovina contains 108 rows
# Botswana contains 5 rows
# Brazil contains 1948 rows
# Brunei Darussalam contains 1 rows
# Bulgaria contains 659 rows
# Burkina Faso contains 4 rows
# Burundi contains 3 rows
# Cambodia contains 30 rows
# Cameroon contains 51 rows
# Canada contains 3395 rows
# Cape Verde contains 3 rows
# Chad contains 1 rows
# Chile contains 206 rows
# China contains 664 rows
# ...

# %% [markdown]
# ### Q13) Calculate The Maximum Value In A Different Column For Each Group

# %%
country_group['ConvertedComp'].get_group('India').max()
# Out:
# 2000000.0

# %% [markdown]
# ### Q14) Group Data By Multiple Columns And Calculate The Sum Of A Numeric Column

# %%
country_group['ConvertedComp'].get_group('India').sum()
# Out:
# 112202602.0

# %% [markdown]
# ### Q15) To Get Country By Details Of People Satisfied In Their Job

# %%
job_sat=df.groupby('JobSat')

# %%
job_sat['Country'].value_counts()
# Out:
# JobSat                              Country
# Neither satisfied nor dissatisfied  United States           1524
#                                     India                   1272
#                                     Germany                  523
#                                     United Kingdom           514
#                                     Canada                   278
#                                                             ...
# Very satisfied                      Oman                       1
#                                     San Marino                 1
#                                     Swaziland                  1
#                                     Syrian Arab Republic       1
#                                     Timor-Leste                1
# Name: Country, Length: 707, dtype: int64

# %% [markdown]
# ### Q16) Calculate The Mean Of A Numeric Column Within Each Group

# %%
country_group=df.groupby('Country')

# %%
country_group['ConvertedComp'].mean()
# Out:
# Country
# Afghanistan                             101953.333333
# Albania                                  21833.700000
# Algeria                                  34924.047619
# Andorra                                 160931.000000
# Angola                                    7764.000000
#                                             ...
# Venezuela, Bolivarian Republic of...     14581.627907
# Viet Nam                                 17233.436782
# Yemen                                    16909.166667
# Zambia                                   10075.375000
# Zimbabwe                                 34046.666667
# Name: ConvertedComp, Length: 179, dtype: float64

# %% [markdown]
# ### Q17) Find The Total Count Of Records In Each Group

# %%
country_group['Student'].get_group('India').value_counts()
# Out:
# No                5443
# Yes, full-time    2944
# Yes, part-time     318
# Name: Student, dtype: int64

# %% [markdown]
# ### Q18) Group Data By Column And Calculate The Median Of A Different Column Within Each Group

# %%
country_group['ConvertedComp'].get_group('Canada').median()
# Out:
# 68705.0

# %% [markdown]
# ### Q19) Calculate The Sum Of A Numeric Column And Rename The Resulting Column

# %%
df.rename(columns={'ConvertedComp':'Salary'})
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
country_group['ConvertedComp'].get_group('Pakistan').sum()
# Out:
# 5112614.0

# %% [markdown]
# ### Q20) Filter Out Groups With A Minimum Count Of Records

# %%
employee_group=df.groupby('Employment')

# %%
employee_group['Age'].min()
# Out:
# Employment
# Employed full-time                                      1.0
# Employed part-time                                      2.0
# Independent contractor, freelancer, or self-employed    1.0
# Not employed, and not looking for work                  1.0
# Not employed, but looking for work                      2.0
# Retired                                                 5.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Q21) Calculate The Minimum Value In A Different Column For Each Group

# %%
country_group['ConvertedComp'].get_group('Pakistan').min()
# Out:
# 100.0

# %% [markdown]
# ### Q22) Lowest Bill

# %%
grouped=tip.groupby('sex')
grouped['total_bill'].min()
# Out:
# sex
# Female    3.07
# Male      7.25
# Name: total_bill, dtype: float64

# %% [markdown]
# ### Q23) Reddit Users In Canada

# %%
social_group['Country'].get_group('Reddit').str.contains('Canada').value_counts(normalize=True)
# Out:
# False    0.937317
# True     0.062683
# Name: Country, dtype: float64

# %% [markdown]
# ### Q24) Retired Canadian Employees

# %%
country_group['Employment'].get_group('Canada').str.contains("Retired").value_counts(normalize=True)
# Out:
# False    0.994904
# True     0.005096
# Name: Employment, dtype: float64

# %% [markdown]
# ### Q25) Instagram Users In India

# %%
social_group['Country'].get_group('Instagram').str.contains('India').value_counts(normalize=True)
# Out:
# False    0.868711
# True     0.131289
# Name: Country, dtype: float64

# %% [markdown]
# ### Q26) Total Bill Average

# %%
grouped=tip.groupby('sex')
grouped['total_bill'].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %% [markdown]
# ### Q27) Group Data By Column And Calculate The Mean Of A Different Column Within Each Group

# %%
country_group['ConvertedComp'].get_group('Canada').mean()
# Out:
# 134018.56490917146

# %% [markdown]
# ### Q28) Filter Out Groups With A Maximum Count Of Records

# %%
employee_group=df.groupby('Employment')

# %%
employee_group['Age'].max()
# Out:
# Employment
# Employed full-time                                      99.0
# Employed part-time                                      99.0
# Independent contractor, freelancer, or self-employed    99.0
# Not employed, and not looking for work                  99.0
# Not employed, but looking for work                      99.0
# Retired                                                 99.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Q29) Calculate The Median Of A Numeric Column Within Each Group

# %%
country_group=df.groupby('Country')

# %%
country_group['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %% [markdown]
# ### Q30) Instagram Users In Canada

# %%
social_group['Country'].get_group('Instagram').str.contains('Canada').value_counts(normalize=True)
# Out:
# False    0.960709
# True     0.039291
# Name: Country, dtype: float64

# %% [markdown]
# ### Q31) What is the average tip of each sex

# %%
grouped_tip=tip.groupby('sex')
grouped_tip['tip'].median()
# Out:
# sex
# Female    2.75
# Male      3.00
# Name: tip, dtype: float64

# %% [markdown]
# ### Q32) To Get Country By Details Of Peoples WorkLoc In Their Job

# %%
work_loc=df.groupby('WorkLoc')

# %%
work_loc['Country'].value_counts()
# Out:
# WorkLoc                                         Country
# Home                                            United States           6700
#                                                 United Kingdom          1642
#                                                 India                   1639
#                                                 Germany                 1338
#                                                 Canada                   902
#                                                                         ...
# Other place, such as a coworking space or cafe  Mozambique                 1
#                                                 Oman                       1
#                                                 Rwanda                     1
#                                                 Syrian Arab Republic       1
#                                                 Timor-Leste                1
# Name: Country, Length: 444, dtype: int64

# %% [markdown]
# ### Q33) Both Lowest Tip

# %%
grouped=tip.groupby('sex')
grouped['tip'].min()
# Out:
# sex
# Female    1.0
# Male      1.0
# Name: tip, dtype: float64
